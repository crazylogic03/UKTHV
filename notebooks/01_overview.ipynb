# %% [markdown]
# # 1. Purpose of This Notebook
#
# This notebook is used to explore and understand all raw datasets before cleaning
# No transformations or modifications are applied
#
# The goal is to identify:
# - Data structure
# - Missing values
# - Duplicates
# - Data quality issues

# %% [markdown]
# # 2. Load All Datasets

# %%
import pandas as pd
import os

# Define the path to the raw datasets
data_dir = '../data/raw_datasets/'

# List of all 9 datasets
datasets = {
    'orders': 'olist_orders_dataset.csv',
    'order_items': 'olist_order_items_dataset.csv',
    'order_payments': 'olist_order_payments_dataset.csv',
    'order_reviews': 'olist_order_reviews_dataset.csv',
    'customers': 'olist_customers_dataset.csv',
    'products': 'olist_products_dataset.csv',
    'sellers': 'olist_sellers_dataset.csv',
    'geolocation': 'olist_geolocation_dataset.csv',
    'category_translation': 'product_category_name_translation.csv'
}

# Dictionary to hold the dataframes
dfs = {}

for name, file_name in datasets.items():
    file_path = os.path.join(data_dir, file_name)
    dfs[name] = pd.read_csv(file_path)
    print(f"Loaded {name} dataset: {file_name}")

# %% [markdown]
# # 3. For EACH Dataset — Do This Analysis

# %% [markdown]
# ## 3.1 Orders Dataset Analysis

# %%
df_current = dfs['orders']

# %% [markdown]
# ### 3.1.1 Basic Structure

# %%
print("--- First 5 rows ---")
display(df_current.head())

print("\n--- Last 5 rows ---")
display(df_current.tail())

print("\n--- Shape ---")
print(df_current.shape)

# %% [markdown]
# **Dataset Content:**
# This dataset contains order-level information including timestamps and order status.

# %% [markdown]
# ### 3.1.2 Data Types

# %%
print("--- Data Types ---")
print(df_current.dtypes)

# %% [markdown]
# **Data Types Observations:**
# - Columns that should be datetime but are strings: `order_purchase_timestamp`, `order_approved_at`, `order_delivered_carrier_date`, `order_delivered_customer_date`, `order_estimated_delivery_date`
# - Categorical columns: `order_status`

# %% [markdown]
# ### 3.1.3 Missing Values

# %%
print("--- Missing Values Per Column ---")
print(df_current.isnull().sum())

print(f"\nTotal Missing Values: {df_current.isnull().sum().sum()}")

# %% [markdown]
# **Missing Values Observations:**
# - High missing values: `order_delivered_customer_date` and `order_delivered_carrier_date`
# - Missing delivery date = critical
# - Missing approved date = less critical (e.g. if canceled)

# %% [markdown]
# ### 3.1.4 Duplicates

# %%
print("--- Duplicate Rows ---")
print(f"Number of duplicate rows: {df_current.duplicated().sum()}")

# %% [markdown]
# **Duplicates Observations:**
# - Duplicates: No duplicate rows exist.
# - Valid if found? No, each order should be unique.

# %% [markdown]
# ### 3.1.5 Statistical Summary

# %%
print("--- Statistical Summary ---")
display(df_current.describe(include='all'))

# %% [markdown]
# **Statistical Summary Observations:**
# - Range: Dates span from 2016 to 2018.
# - Suspicious values: None directly visible.

# %% [markdown]
# ### 3.1.6 Dataset-Specific Observations
#
# **Key Observations (Orders Dataset):**
# - Multiple timestamp columns exist.
# - Order status varies (delivered, canceled, etc.).

# %% [markdown]
# ## 3.2 Order Items Dataset Analysis

# %%
df_current = dfs['order_items']

# %% [markdown]
# ### 3.2.1 Basic Structure

# %%
print("--- First 5 rows ---")
display(df_current.head())

print("\n--- Last 5 rows ---")
display(df_current.tail())

print("\n--- Shape ---")
print(df_current.shape)

# %% [markdown]
# **Dataset Content:**
# This dataset contains individual items within each order, including pricing and freight.

# %% [markdown]
# ### 3.2.2 Data Types

# %%
print("--- Data Types ---")
print(df_current.dtypes)

# %% [markdown]
# **Data Types Observations:**
# - Columns that should be datetime but are strings: `shipping_limit_date`
# - Categorical columns: None directly.

# %% [markdown]
# ### 3.2.3 Missing Values

# %%
print("--- Missing Values Per Column ---")
print(df_current.isnull().sum())

print(f"\nTotal Missing Values: {df_current.isnull().sum().sum()}")

# %% [markdown]
# **Missing Values Observations:**
# - High missing values: None.
# - Critical vs non-critical: All fields critical for analysis.

# %% [markdown]
# ### 3.2.4 Duplicates

# %%
print("--- Duplicate Rows ---")
print(f"Number of duplicate rows: {df_current.duplicated().sum()}")

# %% [markdown]
# **Duplicates Observations:**
# - Duplicates: Duplicate items in the same order may appear if quantity > 1 and listed as separate rows.

# %% [markdown]
# ### 3.2.5 Statistical Summary

# %%
print("--- Statistical Summary ---")
display(df_current.describe(include='all'))

# %% [markdown]
# **Statistical Summary Observations:**
# - Range: Prices and freight values have a wide range.
# - Suspicious values: Extremely high prices.

# %% [markdown]
# ### 3.2.6 Dataset-Specific Observations
#
# **Key Observations (Order Items Dataset):**
# - Multiple items can exist per order.
# - Freight value is calculated per item.

# %% [markdown]
# ## 3.3 Order Payments Dataset Analysis

# %%
df_current = dfs['order_payments']

# %% [markdown]
# ### 3.3.1 Basic Structure

# %%
print("--- First 5 rows ---")
display(df_current.head())

print("\n--- Last 5 rows ---")
display(df_current.tail())

print("\n--- Shape ---")
print(df_current.shape)

# %% [markdown]
# **Dataset Content:**
# This dataset contains payment methods, installments, and values for each order.

# %% [markdown]
# ### 3.3.2 Data Types

# %%
print("--- Data Types ---")
print(df_current.dtypes)

# %% [markdown]
# **Data Types Observations:**
# - Datetime columns: None.
# - Categorical columns: `payment_type`.

# %% [markdown]
# ### 3.3.3 Missing Values

# %%
print("--- Missing Values Per Column ---")
print(df_current.isnull().sum())

print(f"\nTotal Missing Values: {df_current.isnull().sum().sum()}")

# %% [markdown]
# **Missing Values Observations:**
# - High missing values: None expected.
# - Critical vs non-critical: Payment value is critical.

# %% [markdown]
# ### 3.3.4 Duplicates

# %%
print("--- Duplicate Rows ---")
print(f"Number of duplicate rows: {df_current.duplicated().sum()}")

# %% [markdown]
# **Duplicates Observations:**
# - Duplicates: Multiple payments per order are valid (e.g., partial payments).

# %% [markdown]
# ### 3.3.5 Statistical Summary

# %%
print("--- Statistical Summary ---")
display(df_current.describe(include='all'))

# %% [markdown]
# **Statistical Summary Observations:**
# - Range: Values range from 0 to thousands.
# - Suspicious values: 0 value payments.

# %% [markdown]
# ### 3.3.6 Dataset-Specific Observations
#
# **Key Observations (Order Payments Dataset):**
# - Multiple payments per order observed.
# - Different payment types used (credit card, boleto, etc.).

# %% [markdown]
# ## 3.4 Order Reviews Dataset Analysis

# %%
df_current = dfs['order_reviews']

# %% [markdown]
# ### 3.4.1 Basic Structure

# %%
print("--- First 5 rows ---")
display(df_current.head())

print("\n--- Last 5 rows ---")
display(df_current.tail())

print("\n--- Shape ---")
print(df_current.shape)

# %% [markdown]
# **Dataset Content:**
# This dataset contains customer reviews and satisfaction scores for their orders.

# %% [markdown]
# ### 3.4.2 Data Types

# %%
print("--- Data Types ---")
print(df_current.dtypes)

# %% [markdown]
# **Data Types Observations:**
# - Columns that should be datetime but are strings: `review_creation_date`, `review_answer_timestamp`
# - Categorical columns: None.

# %% [markdown]
# ### 3.4.3 Missing Values

# %%
print("--- Missing Values Per Column ---")
print(df_current.isnull().sum())

print(f"\nTotal Missing Values: {df_current.isnull().sum().sum()}")

# %% [markdown]
# **Missing Values Observations:**
# - High missing values: `review_comment_title` and `review_comment_message`.
# - Missing review comment = less critical.
# - Missing review score = critical.

# %% [markdown]
# ### 3.4.4 Duplicates

# %%
print("--- Duplicate Rows ---")
print(f"Number of duplicate rows: {df_current.duplicated().sum()}")

# %% [markdown]
# **Duplicates Observations:**
# - Duplicates: Duplicate reviews might exist if users submit multiple times.

# %% [markdown]
# ### 3.4.5 Statistical Summary

# %%
print("--- Statistical Summary ---")
display(df_current.describe(include='all'))

# %% [markdown]
# **Statistical Summary Observations:**
# - Range: Review scores range from 1 to 5.
# - Suspicious values: None.

# %% [markdown]
# ### 3.4.6 Dataset-Specific Observations
#
# **Key Observations (Order Reviews Dataset):**
# - Missing review comments.
# - Review scores available.

# %% [markdown]
# ## 3.5 Customers Dataset Analysis

# %%
df_current = dfs['customers']

# %% [markdown]
# ### 3.5.1 Basic Structure

# %%
print("--- First 5 rows ---")
display(df_current.head())

print("\n--- Last 5 rows ---")
display(df_current.tail())

print("\n--- Shape ---")
print(df_current.shape)

# %% [markdown]
# **Dataset Content:**
# This dataset contains customer location details and unique identifiers.

# %% [markdown]
# ### 3.5.2 Data Types

# %%
print("--- Data Types ---")
print(df_current.dtypes)

# %% [markdown]
# **Data Types Observations:**
# - Datetime columns: None.
# - Categorical columns: `customer_city`, `customer_state`.

# %% [markdown]
# ### 3.5.3 Missing Values

# %%
print("--- Missing Values Per Column ---")
print(df_current.isnull().sum())

print(f"\nTotal Missing Values: {df_current.isnull().sum().sum()}")

# %% [markdown]
# **Missing Values Observations:**
# - High missing values: Generally complete.
# - Critical vs non-critical: Missing zip code would be critical.

# %% [markdown]
# ### 3.5.4 Duplicates

# %%
print("--- Duplicate Rows ---")
print(f"Number of duplicate rows: {df_current.duplicated().sum()}")

# %% [markdown]
# **Duplicates Observations:**
# - Duplicates: No exact duplicates, but multiple `customer_id`s belong to the same `customer_unique_id`.

# %% [markdown]
# ### 3.5.5 Statistical Summary

# %%
print("--- Statistical Summary ---")
display(df_current.describe(include='all'))

# %% [markdown]
# **Statistical Summary Observations:**
# - Range: Zip codes span across Brazil.
# - Suspicious values: None.

# %% [markdown]
# ### 3.5.6 Dataset-Specific Observations
#
# **Key Observations (Customers Dataset):**
# - Multiple `customer_id`s map to a single `customer_unique_id` (indicates repeat customers).
# - Demographics geographically distributed.

# %% [markdown]
# ## 3.6 Products Dataset Analysis

# %%
df_current = dfs['products']

# %% [markdown]
# ### 3.6.1 Basic Structure

# %%
print("--- First 5 rows ---")
display(df_current.head())

print("\n--- Last 5 rows ---")
display(df_current.tail())

print("\n--- Shape ---")
print(df_current.shape)

# %% [markdown]
# **Dataset Content:**
# This dataset contains product characteristics like category, weight, and dimensions.

# %% [markdown]
# ### 3.6.2 Data Types

# %%
print("--- Data Types ---")
print(df_current.dtypes)

# %% [markdown]
# **Data Types Observations:**
# - Datetime columns: None.
# - Categorical columns: `product_category_name`.

# %% [markdown]
# ### 3.6.3 Missing Values

# %%
print("--- Missing Values Per Column ---")
print(df_current.isnull().sum())

print(f"\nTotal Missing Values: {df_current.isnull().sum().sum()}")

# %% [markdown]
# **Missing Values Observations:**
# - High missing values: `product_category_name` and physical dimensions.
# - Missing category = critical.
# - Missing dimensions = less critical.

# %% [markdown]
# ### 3.6.4 Duplicates

# %%
print("--- Duplicate Rows ---")
print(f"Number of duplicate rows: {df_current.duplicated().sum()}")

# %% [markdown]
# **Duplicates Observations:**
# - Duplicates: No duplicates on `product_id`.

# %% [markdown]
# ### 3.6.5 Statistical Summary

# %%
print("--- Statistical Summary ---")
display(df_current.describe(include='all'))

# %% [markdown]
# **Statistical Summary Observations:**
# - Range: Weights and dimensions vary wildly.
# - Suspicious values: 0 weight.

# %% [markdown]
# ### 3.6.6 Dataset-Specific Observations
#
# **Key Observations (Products Dataset):**
# - Physical dimensions and weight available.
# - Missing product descriptions/categories observed.

# %% [markdown]
# ## 3.7 Sellers Dataset Analysis

# %%
df_current = dfs['sellers']

# %% [markdown]
# ### 3.7.1 Basic Structure

# %%
print("--- First 5 rows ---")
display(df_current.head())

print("\n--- Last 5 rows ---")
display(df_current.tail())

print("\n--- Shape ---")
print(df_current.shape)

# %% [markdown]
# **Dataset Content:**
# This dataset contains seller location details and identifiers.

# %% [markdown]
# ### 3.7.2 Data Types

# %%
print("--- Data Types ---")
print(df_current.dtypes)

# %% [markdown]
# **Data Types Observations:**
# - Datetime columns: None.
# - Categorical columns: `seller_city`, `seller_state`.

# %% [markdown]
# ### 3.7.3 Missing Values

# %%
print("--- Missing Values Per Column ---")
print(df_current.isnull().sum())

print(f"\nTotal Missing Values: {df_current.isnull().sum().sum()}")

# %% [markdown]
# **Missing Values Observations:**
# - High missing values: None expected.
# - Critical vs non-critical: Missing location affects logistics routing.

# %% [markdown]
# ### 3.7.4 Duplicates

# %%
print("--- Duplicate Rows ---")
print(f"Number of duplicate rows: {df_current.duplicated().sum()}")

# %% [markdown]
# **Duplicates Observations:**
# - Duplicates: No duplicates on `seller_id`.

# %% [markdown]
# ### 3.7.5 Statistical Summary

# %%
print("--- Statistical Summary ---")
display(df_current.describe(include='all'))

# %% [markdown]
# **Statistical Summary Observations:**
# - Range: Zip codes across Brazil.
# - Suspicious values: None.

# %% [markdown]
# ### 3.7.6 Dataset-Specific Observations
#
# **Key Observations (Sellers Dataset):**
# - Sellers distributed across different states.
# - Data provides origin coordinates for routing.

# %% [markdown]
# ## 3.8 Geolocation Dataset Analysis

# %%
df_current = dfs['geolocation']

# %% [markdown]
# ### 3.8.1 Basic Structure

# %%
print("--- First 5 rows ---")
display(df_current.head())

print("\n--- Last 5 rows ---")
display(df_current.tail())

print("\n--- Shape ---")
print(df_current.shape)

# %% [markdown]
# **Dataset Content:**
# This dataset contains geographical coordinates mapped to zip code prefixes.

# %% [markdown]
# ### 3.8.2 Data Types

# %%
print("--- Data Types ---")
print(df_current.dtypes)

# %% [markdown]
# **Data Types Observations:**
# - Datetime columns: None.
# - Categorical columns: `geolocation_city`, `geolocation_state`.

# %% [markdown]
# ### 3.8.3 Missing Values

# %%
print("--- Missing Values Per Column ---")
print(df_current.isnull().sum())

print(f"\nTotal Missing Values: {df_current.isnull().sum().sum()}")

# %% [markdown]
# **Missing Values Observations:**
# - High missing values: None expected.
# - Critical vs non-critical: Missing coordinates critical.

# %% [markdown]
# ### 3.8.4 Duplicates

# %%
print("--- Duplicate Rows ---")
print(f"Number of duplicate rows: {df_current.duplicated().sum()}")

# %% [markdown]
# **Duplicates Observations:**
# - Duplicates: High duplication. Many coordinates map to the same zip code prefix.

# %% [markdown]
# ### 3.8.5 Statistical Summary

# %%
print("--- Statistical Summary ---")
display(df_current.describe(include='all'))

# %% [markdown]
# **Statistical Summary Observations:**
# - Range: Latitudes and longitudes within Brazil.
# - Suspicious values: None.

# %% [markdown]
# ### 3.8.6 Dataset-Specific Observations
#
# **Key Observations (Geolocation Dataset):**
# - Multiple rows per zip code prefix.
# - High duplication -> needs aggregation.

# %% [markdown]
# ## 3.9 Category Translation Dataset Analysis

# %%
df_current = dfs['category_translation']

# %% [markdown]
# ### 3.9.1 Basic Structure

# %%
print("--- First 5 rows ---")
display(df_current.head())

print("\n--- Last 5 rows ---")
display(df_current.tail())

print("\n--- Shape ---")
print(df_current.shape)

# %% [markdown]
# **Dataset Content:**
# This dataset contains the mapping from Portuguese product categories to English.

# %% [markdown]
# ### 3.9.2 Data Types

# %%
print("--- Data Types ---")
print(df_current.dtypes)

# %% [markdown]
# **Data Types Observations:**
# - Datetime columns: None.
# - Categorical columns: Both columns.

# %% [markdown]
# ### 3.9.3 Missing Values

# %%
print("--- Missing Values Per Column ---")
print(df_current.isnull().sum())

print(f"\nTotal Missing Values: {df_current.isnull().sum().sum()}")

# %% [markdown]
# **Missing Values Observations:**
# - High missing values: None.
# - Critical vs non-critical: Not critical.

# %% [markdown]
# ### 3.9.4 Duplicates

# %%
print("--- Duplicate Rows ---")
print(f"Number of duplicate rows: {df_current.duplicated().sum()}")

# %% [markdown]
# **Duplicates Observations:**
# - Duplicates: None.

# %% [markdown]
# ### 3.9.5 Statistical Summary

# %%
print("--- Statistical Summary ---")
display(df_current.describe(include='all'))

# %% [markdown]
# **Statistical Summary Observations:**
# - Range: N/A.
# - Suspicious values: None.

# %% [markdown]
# ### 3.9.6 Dataset-Specific Observations
#
# **Key Observations (Category Translation Dataset):**
# - Used to translate categories into English.
# - Small lookup table.

# %% [markdown]
# # 4. Final Summary Table (ALL DATASETS)

# %%
summary_data = []

for name, df in dfs.items():
    summary_data.append({
        'Dataset': name,
        'Rows': df.shape[0],
        'Columns': df.shape[1],
        'Total Missing Values': df.isnull().sum().sum(),
        'Duplicate Rows': df.duplicated().sum()
    })

summary_df = pd.DataFrame(summary_data)
display(summary_df)

# %% [markdown]
# **Overall Summary:**
# - Dataset is large and suitable for analysis
# - Contains real-world issues (missing values, duplicates)
# - Requires proper ETL before analysis

# %% [markdown]
# # Key Takeaways
#
# - The dataset is multi-table and relational
# - Several datasets contain multiple records per key (orders, payments, geolocation)
# - Missing values and inconsistencies are present across datasets
# - Data types need standardization (especially timestamps)
# - The dataset requires merging and cleaning before analysis
#
# **⚠️ IMPORTANT RULES**
# - Clean data: No
# - Drop rows: No
# - Merge datasets: No
# - Modify anything: No
#
# This notebook is ONLY for:
# Understanding and documenting raw data
